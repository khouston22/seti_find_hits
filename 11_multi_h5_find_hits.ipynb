# %% [markdown]
# ### SETI end-to-end narrowband drifting tone detection over multiple h5 spectrogram files
# This notebook sequences through multiple h5 files and looks for drifting narrowband tones.
#
# This is a general-purpose notebook for real observations such as Voyager or commensal pointings.
#
# For each test file, notebook "10_seti_h5_find_hits.ipynb" is called which performs the following:
#
# 1) Inputs a single h5 spectrum file.  The fine FFT size and integration factor are already determined.
# 2) Runs TurboSETI, seticore or bliss and compiles a list of detections and compute time (wall clock)
#
# Note that these sets of files can be done with various branches of seticore2 or bliss,
# and various detection SNR thresholds.  Timing comparisons
# can be made between branches over multiple runs of this notebook.  For each run of this notebook,
# the desired seticore branch needs to be checked out and compiled, and
# the string "test_case" needs to be set in 10_seti_h5_find_hits.ipynb to indicate the branch.
#
# The h5 files can be run from local storage ($SGDIR) or they be run directly from bulk storage by setting variable sg_dir without copying locally.
#
# Plots and .dat files (indicating "hits") are generated in each "10_seti_h5_find_hits.ipynb" call.
#
# There are two modes of operation:
#
# 1) Run everything from this jupyter notebook.  dat files and plots will be created in one run
# 2) Run this notebook to create shell file, run shell file to create .dat files, then run this notebook again to make plots of all the runs
#
# Detailed instructions are below.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import sys
import os
import subprocess
import glob
import matplotlib.pyplot as plt


sg_dir0 = os.getenv('SGDIR') + '/'
if not os.path.isdir(sg_dir0[0:-1]):
    print(f"Warning: ")

parameters_are_undefined = False     # use parameters defined here.  This must be set to False.

# app_to_run examples:
# app_to_run = 'turbo-10'         # turbo-<search_z_threshold ('snr')> 
# app_to_run = 'turbo-3'         # turbo-<search_z_threshold ('snr')> 
# app_to_run = 'seticore-10'      # seticore-<search_z_threshold ('snr')>
# app_to_run = 'bliss-10-0'       # use special file 'GBT_spliced_PFB_response.f32'
# app_to_run = 'bliss-10-8'     # bliss-use for setigen h5 files - <search_z_threshold>-<pfb_order>
# app_to_run = 'bliss-10-12'      # bliss- 12th order PFB (GBT)
# app_to_run = 'bliss-10-16'      # bliss- 16th order PFB (GBT)
# app_to_run = 'Bliss_C+-4_dat_0'     # plot dat file for bliss runs 
# app_to_run = 'Bliss_C0-11_dat_0'     # plot dat file for bliss runs 
# app_to_run = 'seticore-sc4-Base-10_dat_0'      # seticore-test_case_dat_plotcase run from dat file only (replot)
# app_to_run = 'seticore-sc4-Base-10_dat_2'      # seticore-test_case_dat_plotcase run from dat file only (replot)

# app_to_run_list = ['seticore-7','seticore-8','seticore-9','seticore-10']
# app_to_run_list = ['bliss-7-0','bliss-10-0']
# app_to_run_list = ['seticore-2','seticore-3','seticore-4','seticore-5','seticore-6','seticore-7']
# app_to_run_list = ['bliss-1-0','bliss-1.5-0','bliss-2-0','bliss-3-0','bliss-4-0','bliss-5-0','bliss-6-0','bliss-7-0']
# app_to_run_list = ['turbo-1.0','turbo-1.5','turbo-2.0','turbo-3.0']
app_to_run_list = ['seticore-10','turbo-3','bliss-10-0']
# app_to_run_list = ['seticore-10','turbo-3']
# app_to_run_list = ['seticore-10']
# app_to_run_list = ['seticore-3']    # for sc0 =~ turbo-3
# app_to_run_list = ['bliss-10-0']
# app_to_run_list = ['bliss-7-0']
# app_to_run_list = ['turbo-3']
n_app_to_run = len(app_to_run_list)
print(f'{n_app_to_run} app(s) to run: \n',app_to_run_list)

min_abs_drift_Hz_sec0 = 0.                  # band around 0 Hz/sec to exclude in search app
# min_abs_drift_Hz_sec_list = [.01,.05,.10,.15,.20]   # band around 0 Hz/sec to exclude in plots
# min_abs_drift_Hz_sec_list = [.01,.10]   # band around 0 Hz/sec to exclude in plots
min_abs_drift_Hz_sec_list = [.01]   # band around 0 Hz/sec to exclude in plots

n_drift_limit = len(min_abs_drift_Hz_sec_list)
min_abs_drift_Hz_sec_list.sort()
print(f'{n_drift_limit} drift limits(s) to plot: \n',min_abs_drift_Hz_sec_list)

bliss_enable_negate_drift = True

# Two modes of operation:
# Mode 1: run everything from this jupyter notebook.  dat files and plots will be created in one run
#       In this notebook, set:  mode_string = 'mode1', and run all
# Mode 2: run this notebook to create shell file, run shell file to create .dat files, 
#       then run this notebook again to make plots of all the runs
#       2a) $ rm run_str_log.txt
#       2b) In this notebook, set: mode_string = 'mode2_1stpass', and run all
#           This will create shell commands in run_str_log.txt
#       2c) Command line actions similar to this to run search algs and create dat files:
#           $ cp run_str_log.txt run_str_log.sh
#           $ chmod +x run_str_log.sh
#           $ ./run_str_log.sh
#       2d) In this notebook, set: mode_string = 'mode2_2ndpass', and run all
#       Be careful not to change parameters between generating shell commands and running plots. 

mode_string = 'mode1'           # run everything from this notebook in a single pass (simplest)
# mode_string = 'mode2_1stpass'   # run this notebook to generate shell scripts
# mode_string = 'mode2_2ndpass'   # run this notebook after running shell scripts to do plots

if (mode_string.lower()=='mode1'):              # run everything from this notebook in a single pass
    run_search_app = True               
    plot_shell_run_only = False         
elif (mode_string.lower()=='mode2_1stpass'):    # run this notebook to generate shell scripts
    run_search_app = False                      # False to just generate command lines for shell runs
    plot_shell_run_only = False                
elif (mode_string.lower()=='mode2_2ndpass'):    # run this notebook after running shell scripts to do plots
    run_search_app = False               
    plot_shell_run_only = True                  # =True to plot dat files from a previous shell run
else:
    raise ValueError(f'Error: mode string {mode_string} not recognized')

display_figs01 = False
plot_all_dets = True
verbose = True

plot_sg_psd_zoom = False
plot_sg_zoom = False
plot_psd_zoom = False
plot_multi_psd_zoom = False

plot_sg_wb = False
plot_psd_wb = False
plot_channel_idx_dets = True
plot_det_histogram = False

max_n_BB_zoom_plots = 20
max_n_NB_zoom_plots = 40
max_n_multi_zoom_plots = 12
zoom_NB_bw_MHz = .030   # +/- 15 KHz
zoom_min_max_freq_MHz = []
zoom_min_max_drift_rate = []
beep_when_h5_complete = False

run_turbo = False
fb_ext = '.h5'

h5_backup_subdir = ''
base_h5_name = '' 

if (1):
    search_max_drift = 10    # Hz/sec
    search_min_drift = -10   # ignored except for plotting
        
dc_blank = True

base_h5_name_list = []
sg_dir = sg_dir0
 
if (0):
    # synthetic noise with chirps inserted
    h5_file_spec = ['synthetic_chi2_pfb0_0dB_8ch-201sig-5Hzpersec-c15dB-3Hz.h5']
    fig_dir = './plots/'  
elif (0):
    # synthetic noise with chirps inserted
    h5_file_spec = ['syn*Hz.h5']
    fig_dir = './chi2_sig_plots/'  
elif (0):
    # synthetic noise without chirps inserted for FAR (false alarm rate) testing
    h5_file_spec = ['syn*ch.h5']
    fig_dir = './chi2_FAR_plots/'  
elif (0):
    h5_file_spec = ['blc*16209_MESSIER031*.h5']
    fig_dir = './MESS_plots/'  
elif (0):
    # h5_file_spec = ['blc*16209_MESSIER031*.h5','blc*HIP*.h5','blc*TIC*.h5','gbt-chirp80*.h5'];
    h5_file_spec = ['blc7*16209_MESSIER031*.h5']  # 
    # h5_file_spec = ['blc73*16209_MESSIER031*.h5'];
    fig_dir = './full_plots/'
elif (0):
    bliss_enable_negate_drift = False
    h5_file_spec = ['blc76*16209_MESSIER031*3Hz.h5']  # 
    fig_dir = './drift_sign_plots/' 
elif (1):
    bliss_enable_negate_drift = False
    sg_dir = '/datag/public/seti_benchmarking/multichirp_setigen/'
    h5_file_spec = ['*366*.h5'];
    fig_dir = './drift_sign_plots/'       
elif (0):
    sg_dir = '/mnt/d/data_files/seti_benchmarking/HIP_TIC_C_59239/'
    h5_file_spec = ['*.h5'];
    fig_dir = './HIP_TIC_C_59239_plots/'  
elif (0):
    sg_dir = '/mnt/d/data_files/seti_benchmarking/HIP_TIC_L_59756/'
    h5_file_spec = ['*.h5'];
    fig_dir = './HIP_TIC_L_59756_plots/'  
elif (0):
    sg_dir = '/mnt/d/data_files/seti_benchmarking/HIP_TIC_X_59189/'
    h5_file_spec = ['*.h5'];
    fig_dir = './HIP_TIC_X_59189_plots/'  
elif (0):
    # examples of Bliss drift rates at rails
    sg_dir = '/mnt/d/data_files/seti_benchmarking/HIP_TIC_C_59239/'
    h5_file_spec = ['blc10*.h5','blc20*.h5','blc30*.h5','blc35*.h5','blc37*.h5'];
    plot_channel_idx_dets = True
    plot_det_histogram = True
    fig_dir = './HIP_TIC_C_59239_channel_plots/'  
elif (1):
    h5_file_spec = 'gbt-chirp80*.h5';
    fig_dir = './chirp_plots/'  
elif (1):
    # Nsti=16
    sg_dir = '/mnt/d/data_files/seti_benchmarking/KEPLER-160/'
    h5_file_spec = ['*.h5']
    fig_dir = './KEPLER_plots/'  
elif (0):
    # part of full_plots
    sg_dir = '/mnt/d/data_files/seti_benchmarking/MESS_58832/'
    h5_file_spec = ['*.h5']
    fig_dir = './mess_plots/'  
elif (0):
    h5_file_spec = ['blc*HIP*.h5','blc*TIC*.h5'];
    fig_dir = './HIP_TIC_plots/'  
elif (0):
    # h5_file_spec = '*.h5';
    h5_file_spec = 'blc*16209_MESSIER031*.h5';
    # h5_file_spec = '*TIC159107668_0016*.h5';
    fig_dir = './plots/'  
elif (0):
    sg_dir = '/mnt/d/data_files/seti_benchmarking/mlc/'
    h5_file_spec = '*HIP*.h5';
    # base_h5_name_list = [
    #     'spliced_blc0001020304050607_guppi_57517_08789_HIP54677_0009.gpuspec.0000.h5',
    #     'spliced_blc0001020304050607_guppi_57517_09209_HIP53759_0010.gpuspec.0000.h5']
    fig_dir = './mlc_plots/'  
elif (0):
    # problems reading file
    sg_dir = '/mnt/d/data_files/seti_benchmarking/lband_rfi_single_node/'
    h5_file_spec = '*.fil';
    fig_dir = './lband_rfi_plots/'  
elif (0):
    # problems reading file
    sg_dir = '/mnt/d/data_files/seti_benchmarking/lband_clean_single_node/'
    h5_file_spec = '*.fil';
    fig_dir = './lband_clean_plots/'  
elif (0):
    sg_dir = '/mnt/d/data_files/seti_benchmarking/Sample_Datasets_ASP/Catalogued_Signals/'
    h5_file_spec = '*.h5';
    fig_dir = './ASP_plots/'  
    plot_sg_psd_zoom = True
elif (1):
    sg_dir = '/mnt/d/data_files/seti_benchmarking/Sample_Datasets_ASP/Horseshoe_Artifact/'
    h5_file_spec = '*.h5';
    fig_dir = './ASP_plots/'  
    plot_sg_psd_zoom = False
elif (0):
    # problems reading file
    sg_dir = '/mnt/d/data_files/seti_benchmarking/cosmic_h5/'
    h5_file_spec = '*.h5';
    fig_dir = './cosmic_plots/'  
    plot_sg_psd_zoom = True
elif (0):
    base_h5_name_list = [
        'gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-45.81sec-1024K-Nsti-16.rawspec.0000.h5',
        'gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5']
    zoom_bw_MHz = .012  # +/- 6 KHz
    fig_dir = './gbt_chirp_plots/'
elif (0):
    base_h5_name_list = [
        'blc23_guppi_59046_80036_DIAG_VOYAGER-1_0011-1024K-Nsti-16.rawspec.0000.h5',
        'blc43_guppi_59103_01984_DIAG_KEPLER-160_0010-1024K-Nsti-16.rawspec.0000.h5',
        'blc45_guppi_59103_01984_DIAG_KEPLER-160_0010-1024K-Nsti-16.rawspec.0000.h5']
    fig_dir = './plots/'

# if file spec entered, obtain list of files

if (len(base_h5_name_list)==0):
    if not isinstance(h5_file_spec,list):
        for file in glob.glob(sg_dir+h5_file_spec):
            base_h5_name_list.append(os.path.basename(file))
    else:
        for i_list in range(len(h5_file_spec)):
            for file in glob.glob(sg_dir+h5_file_spec[i_list]):
                base_h5_name_list.append(os.path.basename(file))

n_h5_file = len(base_h5_name_list)

print(f'SG directory={sg_dir}')
print(f'base_h5_name_list= ({n_h5_file} files)')
for i_h5 in range(n_h5_file):
    print(f'{base_h5_name_list[i_h5]}')
             
print(f'Figures will appear in in {fig_dir}')
# Out:
# 3 app(s) to run:
#  ['seticore-10', 'turbo-3', 'bliss-10-0']
# 1 drift limits(s) to plot:
#  [0.01]
# SG directory=/datag/public/seti_benchmarking/multichirp_setigen/
# base_h5_name_list= (1 files)
# gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5
# Figures will appear in in ./drift_sign_plots/

# %% [markdown]
# #### Run end-to-end test over parameter sweeps

# %%
for i_app in range(n_app_to_run):
    app_to_run = app_to_run_list[i_app]

    for i_h5 in range(n_h5_file):
        base_h5_name = base_h5_name_list[i_h5]
        print(f'\n\n{mode_string} {app_to_run}: h5 file {i_h5+1} of {n_h5_file}: {base_h5_name}\n\n')
        
        try:      
            # %run ./10_seti_h5_find_hits.ipynb
        except SystemExit:
            print(f'Shell command saved')
        except:
            print(f'\nError Occurred for h5 file {base_h5_name}, skip\n\n')
# Out:
# mode1 seticore-10: h5 file 1 of 1: gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5
#
#
# Running Seticore2 for |drifts| >= 0.00
# List of minimum |drifts| for plotting: [0.01]
# search_app_name='$SC2/seticore2', search_app_string='Seticore2', branch='sc4', test_case='sc4-Base-10', search_z_threshold=10.0
# h5 directory = /datag/public/seti_benchmarking/multichirp_setigen/
# base_h5_name = gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5
# Drift Search Range: -10.00 to 10.00 Hz/sec
# base_h5_name = '/datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5'
# h5 file found
# h5 File size =    793 MB, n_h5_files = 1
#
# GBT, 2020-09-22T04:24:28.000, mjd_day=59114, TMC1, ra_deg = 70.441, dec_deg = 25.691
# ctr_freq_MHz = 6004.395, obs_bw_MHz = np.float64(11.71875), chan_bw = 2929687.500, f_min_MHz = 5998.535, f_max_MHz = 6010.254
#
# t_obs = 366.504, n_coarse_channels = np.int32(4), n_bits = np.int32(32), chan_bw = 2929687.500
# fs_coarse = 2929687.500, fine_fft_size = np.int32(1048576), n_sti = 16, n_lti = 64, n_avg = 1024
# t_coarse = 3.413e-07, t_fine = 0.358, t_res = 5.727
# fs_coarse = 2929687.500, fs_fine = 2.794
# Nfft=1024K, Nsti=16, Nlti=64, 367 sec  sc4-Base-10
#  FineFFT-1024K-Nsti-16
# fig_name_base = 'gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000'
# No setigen data available
# 0 Inserted chirps
# h5_drift_rate =  [] ...
# h5_f_start =  [] ...
# h5_channel_idx =  [] ...
# $SC2/seticore2 /datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5 --max_drift=10 --min_drift=0.0 --fft_size 1048576 --snr=10.0  --output=/datax/scratch/khouston/search_results/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.sc4-Base-10.dat
# dedoppler elapsed time: 7s
# Seticore search: 6.99 sec 1.75 sec/coarse channel
# df_dash = 0.002861 MHz
# NB: range(0, 40)
# seti_h5_find_hits completed, 9.03 sec
#
#
#
# mode1 turbo-3: h5 file 1 of 1: gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5
#
#
# Running turboSETI for |drifts| >= 0.00
# List of minimum |drifts| for plotting: [0.01]
# search_app_name='turboSETI', search_app_string='turboSETI', branch='', test_case='turboSETI-3', search_z_threshold=3.0
# h5 directory = /datag/public/seti_benchmarking/multichirp_setigen/
# base_h5_name = gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5
# Drift Search Range: -10.00 to 10.00 Hz/sec
# base_h5_name = '/datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5'
# h5 file found
# h5 File size =    793 MB, n_h5_files = 1
#
# GBT, 2020-09-22T04:24:28.000, mjd_day=59114, TMC1, ra_deg = 70.441, dec_deg = 25.691
# ctr_freq_MHz = 6004.395, obs_bw_MHz = np.float64(11.71875), chan_bw = 2929687.500, f_min_MHz = 5998.535, f_max_MHz = 6010.254
#
# t_obs = 366.504, n_coarse_channels = np.int32(4), n_bits = np.int32(32), chan_bw = 2929687.500
# fs_coarse = 2929687.500, fine_fft_size = np.int32(1048576), n_sti = 16, n_lti = 64, n_avg = 1024
# t_coarse = 3.413e-07, t_fine = 0.358, t_res = 5.727
# fs_coarse = 2929687.500, fs_fine = 2.794
# Nfft=1024K, Nsti=16, Nlti=64, 367 sec  turboSETI-3
#  FineFFT-1024K-Nsti-16
# fig_name_base = 'gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000'
# No setigen data available
# 0 Inserted chirps
# h5_drift_rate =  [] ...
# h5_f_start =  [] ...
# h5_channel_idx =  [] ...
#
# turbo_seti version 2.3.2
# blimpy version 2.1.4
# h5py version 3.13.0
# hdf5plugin version 5.1.0
# HDF5 library version 1.14.6
#
#
# data_handler    INFO     From nfpc=1048576, n_fine_nchans=4194304 and n_coarse_chan=4
# HDF5 header info: {'DIMENSION_LABELS': array(['time', 'feed_id', 'frequency'], dtype=object), 'az_start': np.float64(0.0), 'data_type': np.int32(1), 'fch1': np.float64(5998.53515625), 'foff': np.float64(2.7939677238464355e-06), 'ibeam': np.int32(-1), 'machine_id': np.int32(20), 'nbeams': np.int32(1), 'nbits': np.int32(32), 'nchans': np.int32(4194304), 'nfpc': np.int32(1048576), 'nifs': np.int32(1), 'rawdatafile': 'gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec.0000.raw', 'source_name': 'TMC1', 'src_dej': <Angle 25.6911 deg>, 'src_raj': <Angle 4.69605333 hourangle>, 'telescope_id': np.int32(6), 'tsamp': np.float64(5.726623061333328), 'tstart': np.float64(59114.183657407404), 'za_start': np.float64(0.0)}
#
# Starting ET search with parameters: datafile=/datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5, max_drift=10, min_drift=0.0, snr=3.0, out_dir=/datax/scratch/khouston/search_results/, coarse_chans=None, flagging=False, n_coarse_chan=4, kernels=None, gpu_id=0, gpu_backend=False, blank_dc=True, precision=1, append_output=False, log_level_int=20, obs_info={'pulsar': 0, 'pulsar_found': 0, 'pulsar_dm': 0.0, 'pulsar_snr': 0.0, 'pulsar_stats': array([0., 0., 0., 0., 0., 0.]), 'RFI_level': 0.0, 'Mean_SEFD': 0.0, 'psrflux_Sens': 0.0, 'SEFDs_val': [0.0], 'SEFDs_freq': [0.0], 'SEFDs_freq_up': [0.0]}
#
# Computed drift rate resolution: 0.007744301232039325
#
# find_doppler.0  INFO     Spectra 0 1st 3 values: [434639.2  319892.78 319074.06]
# find_doppler.0  INFO     Spectra 1 1st 3 values: [473474.53 348017.28 405984.94]
# find_doppler.0  INFO     Top hit found! SNR 751.730286, Drift Rate 0.007744, index 524288
# find_doppler.1  INFO     Top hit found! SNR 3.894188, Drift Rate -9.997893, index 263108
# find_doppler.1  INFO     Top hit found! SNR 4.009018, Drift Rate -9.796541, index 270361
# find_doppler.1  INFO     Top hit found! SNR 3.571419, Drift Rate -9.571957, index 277612
# find_doppler.1  INFO     Top hit found! SNR 3.774654, Drift Rate -9.246696, index 284868
# find_doppler.1  INFO     Top hit found! SNR 3.854347, Drift Rate -8.967901, index 292107
# find_doppler.1  INFO     Top hit found! SNR 3.975554, Drift Rate -8.673617, index 299356
# find_doppler.1  INFO     Top hit found! SNR 4.093544, Drift Rate -8.363845, index 306600
# find_doppler.1  INFO     Top hit found! SNR 4.350087, Drift Rate -8.139260, index 313850
# find_doppler.1  INFO     Top hit found! SNR 4.179449, Drift Rate -7.968886, index 321107
# find_doppler.1  INFO     Top hit found! SNR 4.397619, Drift Rate -7.736557, index 328351
# find_doppler.1  INFO     Top hit found! SNR 4.415509, Drift Rate -7.535205, index 335606
# find_doppler.1  INFO     Top hit found! SNR 4.739976, Drift Rate -7.194456, index 342856
# find_doppler.1  INFO     Top hit found! SNR 4.790527, Drift Rate -7.055058, index 350109
# find_doppler.1  INFO     Top hit found! SNR 4.870367, Drift Rate -6.714309, index 357353
# find_doppler.1  INFO     Top hit found! SNR 5.178861, Drift Rate -6.520701, index 364605
# find_doppler.1  INFO     Top hit found! SNR 5.173624, Drift Rate -6.234162, index 371851
# find_doppler.1  INFO     Top hit found! SNR 5.318438, Drift Rate -5.986345, index 379099
# find_doppler.1  INFO     Top hit found! SNR 5.618171, Drift Rate -5.746272, index 386351
# find_doppler.1  INFO     Top hit found! SNR 5.772040, Drift Rate -5.436500, index 393599
# find_doppler.1  INFO     Top hit found! SNR 6.149891, Drift Rate -5.196426, index 400847
# find_doppler.1  INFO     Top hit found! SNR 6.509130, Drift Rate -4.948608, index 408098
# find_doppler.1  INFO     Top hit found! SNR 6.838704, Drift Rate -4.654325, index 415344
# find_doppler.1  INFO     Top hit found! SNR 7.039164, Drift Rate -4.414252, index 422594
# find_doppler.1  INFO     Top hit found! SNR 7.596184, Drift Rate -4.197411, index 429843
# find_doppler.1  INFO     Top hit found! SNR 7.745139, Drift Rate -3.949594, index 437094
# find_doppler.1  INFO     Top hit found! SNR 8.259346, Drift Rate -3.678543, index 444343
# find_doppler.1  INFO     Top hit found! SNR 8.717427, Drift Rate -3.399748, index 451591
# find_doppler.1  INFO     Top hit found! SNR 9.162350, Drift Rate -3.190652, index 458841
# find_doppler.1  INFO     Top hit found! SNR 10.045102, Drift Rate -2.904113, index 466089
# find_doppler.1  INFO     Top hit found! SNR 10.794762, Drift Rate -2.664040, index 473337
# find_doppler.1  INFO     Top hit found! SNR 11.873886, Drift Rate -2.400733, index 480586
# find_doppler.1  INFO     Top hit found! SNR 12.735323, Drift Rate -2.145171, index 487836
# find_doppler.1  INFO     Top hit found! SNR 14.914516, Drift Rate -1.897354, index 495085
# find_doppler.1  INFO     Top hit found! SNR 16.592377, Drift Rate -1.649536, index 502335
# find_doppler.1  INFO     Top hit found! SNR 18.800722, Drift Rate -1.401718, index 509584
# find_doppler.1  INFO     Top hit found! SNR 21.943537, Drift Rate -1.146157, index 516833
# find_doppler.1  INFO     Top hit found! SNR 75.413773, Drift Rate -0.007744, index 524288
# find_doppler.1  INFO     Top hit found! SNR 31.059303, Drift Rate -0.635033, index 531331
# find_doppler.1  INFO     Top hit found! SNR 36.728050, Drift Rate -0.379471, index 538580
# find_doppler.1  INFO     Top hit found! SNR 42.071354, Drift Rate -0.123909, index 545829
# find_doppler.1  INFO     Top hit found! SNR 41.620197, Drift Rate 0.116165, index 553079
# find_doppler.1  INFO     Top hit found! SNR 35.849861, Drift Rate 0.387215, index 560327
# find_doppler.1  INFO     Top hit found! SNR 30.526176, Drift Rate 0.627288, index 567577
# find_doppler.1  INFO     Top hit found! SNR 27.450212, Drift Rate 0.882850, index 574826
# find_doppler.1  INFO     Top hit found! SNR 22.214775, Drift Rate 1.138412, index 582075
# find_doppler.1  INFO     Top hit found! SNR 19.516571, Drift Rate 1.393974, index 589324
# find_doppler.1  INFO     Top hit found! SNR 16.916182, Drift Rate 1.634048, index 596574
# find_doppler.1  INFO     Top hit found! SNR 14.494700, Drift Rate 1.897354, index 603822
# find_doppler.1  INFO     Top hit found! SNR 13.333650, Drift Rate 2.160660, index 611071
# find_doppler.1  INFO     Top hit found! SNR 12.030581, Drift Rate 2.392989, index 618322
# find_doppler.1  INFO     Top hit found! SNR 10.846830, Drift Rate 2.687273, index 625568
# find_doppler.1  INFO     Top hit found! SNR 10.047230, Drift Rate 2.911857, index 632820
# find_doppler.1  INFO     Top hit found! SNR 9.622156, Drift Rate 3.167419, index 640070
# find_doppler.1  INFO     Top hit found! SNR 8.853652, Drift Rate 3.407493, index 647317
# find_doppler.1  INFO     Top hit found! SNR 8.264481, Drift Rate 3.678543, index 654564
# find_doppler.1  INFO     Top hit found! SNR 8.018885, Drift Rate 3.934105, index 661814
# find_doppler.1  INFO     Top hit found! SNR 7.249409, Drift Rate 4.181922, index 669063
# find_doppler.1  INFO     Top hit found! SNR 7.265011, Drift Rate 4.476206, index 676311
# find_doppler.1  INFO     Top hit found! SNR 6.639955, Drift Rate 4.716280, index 683562
# find_doppler.1  INFO     Top hit found! SNR 6.051536, Drift Rate 4.925375, index 690814
# find_doppler.1  INFO     Top hit found! SNR 6.390839, Drift Rate 5.149961, index 698063
# find_doppler.1  INFO     Top hit found! SNR 5.647995, Drift Rate 5.467477, index 705306
# find_doppler.1  INFO     Top hit found! SNR 5.709021, Drift Rate 5.684317, index 712558
# find_doppler.1  INFO     Top hit found! SNR 5.370699, Drift Rate 5.908902, index 719814
# find_doppler.1  INFO     Top hit found! SNR 5.214266, Drift Rate 6.241907, index 727055
# find_doppler.1  INFO     Top hit found! SNR 4.986847, Drift Rate 6.443259, index 734306
# find_doppler.1  INFO     Top hit found! SNR 5.273291, Drift Rate 6.722054, index 741551
# find_doppler.1  INFO     Top hit found! SNR 4.728002, Drift Rate 6.869195, index 748811
# find_doppler.1  INFO     Top hit found! SNR 4.557971, Drift Rate 7.225433, index 756054
# find_doppler.1  INFO     Top hit found! SNR 4.519688, Drift Rate 7.566182, index 763298
# find_doppler.1  INFO     Top hit found! SNR 4.365811, Drift Rate 7.736557, index 770549
# find_doppler.1  INFO     Top hit found! SNR 4.158632, Drift Rate 7.961142, index 777806
# find_doppler.1  INFO     Top hit found! SNR 4.047380, Drift Rate 8.185726, index 785056
# find_doppler.1  INFO     Top hit found! SNR 3.967151, Drift Rate 8.503242, index 792296
# find_doppler.1  INFO     Top hit found! SNR 3.927902, Drift Rate 8.650385, index 799554
# find_doppler.1  INFO     Top hit found! SNR 3.717346, Drift Rate 9.045343, index 806797
# find_doppler.1  INFO     Top hit found! SNR 3.696572, Drift Rate 9.355116, index 814042
# find_doppler.1  INFO     Top hit found! SNR 3.544518, Drift Rate 9.486769, index 821303
# find_doppler.1  INFO     Top hit found! SNR 4.400878, Drift Rate 9.804285, index 828548
# find_doppler.1  INFO     Top hit found! SNR 3.507112, Drift Rate 9.897217, index 835805
# find_doppler.2  INFO     Top hit found! SNR 75.929550, Drift Rate 0.015489, index 524287
# find_doppler.3  INFO     Top hit found! SNR 76.169937, Drift Rate -0.007744, index 524288
# \TurboSeti Search complete 143.86 sec 35.97 sec/coarse channel
# /datax/scratch/khouston/search_results/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.dat
# df_dash = 0.002861 MHz
# seti_h5_find_hits completed, 146.44 sec
#
#
#
# mode1 bliss-10-0: h5 file 1 of 1: gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5
#
#
# bliss_device_str='"cuda:0"', test_case='Bliss-10-0', pfb_file='GBT_spliced_PFB_response.f32', n_eq_ch=64
# Running Bliss2 for |drifts| >= 0.00
# List of minimum |drifts| for plotting: [0.01]
# search_app_name='$BL2/bliss_find_hits', search_app_string='Bliss2', branch='Bliss', test_case='Bliss-10-0', search_z_threshold=10.0
# h5 directory = /datag/public/seti_benchmarking/multichirp_setigen/
# Bliss drift intervals:  [-10.  -5.   0.   5.  10.]
# base_h5_name = gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5
# Drift Search Range: -10.00 to 10.00 Hz/sec
# base_h5_name = '/datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5'
# h5 file found
# h5 File size =    793 MB, n_h5_files = 1
#
# GBT, 2020-09-22T04:24:28.000, mjd_day=59114, TMC1, ra_deg = 70.441, dec_deg = 25.691
# ctr_freq_MHz = 6004.395, obs_bw_MHz = np.float64(11.71875), chan_bw = 2929687.500, f_min_MHz = 5998.535, f_max_MHz = 6010.254
#
# t_obs = 366.504, n_coarse_channels = np.int32(4), n_bits = np.int32(32), chan_bw = 2929687.500
# fs_coarse = 2929687.500, fine_fft_size = np.int32(1048576), n_sti = 16, n_lti = 64, n_avg = 1024
# t_coarse = 3.413e-07, t_fine = 0.358, t_res = 5.727
# fs_coarse = 2929687.500, fs_fine = 2.794
# Nfft=1024K, Nsti=16, Nlti=64, 367 sec  Bliss-10-0
#  FineFFT-1024K-Nsti-16
# fig_name_base = 'gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000'
# No setigen data available
# 0 Inserted chirps
# h5_drift_rate =  [] ...
# h5_f_start =  [] ...
# h5_channel_idx =  [] ...
# $BL2/bliss_find_hits /datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5 -c 0 --number-coarse 4 --nchan-per-coarse 1048576 --excise-dc --device "cuda:0"  --equalizer-channel $BL_EQ/GBT_spliced_PFB_response.f32 --min-drift -10 --max-drift -4.75 --snr 10.0  --output /datax/scratch/khouston/search_results/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.Bliss-10-0_1of4.dat
# HDF5-DIAG: Error detected in HDF5 (1.14.6):
#   #000: H5O.c line 158 in H5Oopen(): unable to synchronously open object
#     major: Object header
#     minor: Can't open object
#   #001: H5O.c line 119 in H5O__open_api_common(): unable to open object
#     major: Object header
#     minor: Can't open object
#   #002: H5VLcallback.c line 5577 in H5VL_object_open(): object open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 5544 in H5VL__object_open(): object open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_object.c line 88 in H5VL__native_object_open(): unable to open object by name
#     major: Object header
#     minor: Can't open object
#   #005: H5Oint.c line 593 in H5O_open_name(): object not found
#     major: Object header
#     minor: Object not found
#   #006: H5Gloc.c line 424 in H5G_loc_find(): can't find object
#     major: Symbol table
#     minor: Object not found
#   #007: H5Gtraverse.c line 824 in H5G_traverse(): internal path traversal failed
#     major: Symbol table
#     minor: Object not found
#   #008: H5Gtraverse.c line 596 in H5G__traverse_real(): traversal operator failed
#     major: Symbol table
#     minor: Callback failed
#   #009: H5Gloc.c line 381 in H5G__loc_find_cb(): object 'setigen' doesn't exist
#     major: Symbol table
#     minor: Object not found
# $BL2/bliss_find_hits /datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5 -c 0 --number-coarse 4 --nchan-per-coarse 1048576 --excise-dc --device "cuda:0"  --equalizer-channel $BL_EQ/GBT_spliced_PFB_response.f32 --min-drift -5.25 --max-drift 0.0 --snr 10.0  --output /datax/scratch/khouston/search_results/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.Bliss-10-0_2of4.dat
# $BL2/bliss_find_hits /datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5 -c 0 --number-coarse 4 --nchan-per-coarse 1048576 --excise-dc --device "cuda:0"  --equalizer-channel $BL_EQ/GBT_spliced_PFB_response.f32 --min-drift 0.0 --max-drift 5.25 --snr 10.0  --output /datax/scratch/khouston/search_results/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.Bliss-10-0_3of4.dat
# $BL2/bliss_find_hits /datag/public/seti_benchmarking/multichirp_setigen/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.h5 -c 0 --number-coarse 4 --nchan-per-coarse 1048576 --excise-dc --device "cuda:0"  --equalizer-channel $BL_EQ/GBT_spliced_PFB_response.f32 --min-drift 4.75 --max-drift 10 --snr 10.0  --output /datax/scratch/khouston/search_results/gbt-chirp80-0.0020V-6002.20-6003.80-m10.0-10.0-Hzsec-366.50sec-1024K-Nsti-16.rawspec.0000.Bliss-10-0_4of4.dat
#
# Bliss search: 176.31 sec 44.08 sec/coarse channel
# df_dash = 0.002861 MHz
# NB: range(0, 40)
# seti_h5_find_hits completed, 178.43 sec

# %%
import os

print('All Runs Done')

# Beep 2 times
for i_beep in range(2):
    try:
        # Beep in WSL
        if os.system("powershell.exe '[console]::beep(261.6,700)'") !=0:
            raise Exception('powershell.exe not found')
    except:
        # linux, probably doesn't work
        print('Beep!')
        os.system("echo -ne '\a'")
# Out:
# All Runs Done
# Beep!
# -ne
# Beep!
# -ne
# sh: 1: powershell.exe: not found
# sh: 1: powershell.exe: not found
